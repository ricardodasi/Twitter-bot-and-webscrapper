# %%
#Project for Python web scraping and twitter posting bot for Magic the Gathering project:


#import libraries

import requests 

#testing get request with requests library to download website

page = requests.get('https://scryfall.com/card/eld/197/oko-thief-of-crowns.html')

page
# Out:
# <Response [200]>

# %%
#checking status of download, number starting with 2 suggests success

page.status_code
# Out:
# 200

# %%
#we check the html contents

page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr">\n  <head>\n    <meta charset="utf-8">\n      <title>Oko, Thief of Crowns \xc2\xb7 Throne of Eldraine (ELD) #197 \xc2\xb7 Scryfall Magic: The Gathering Search</title>\n    \n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\n<link rel="preconnect" href="https://assets.scryfall.com" crossorigin="true" />\n<link rel="preconnect" href="https://img.scryfall.com" crossorigin="true" />\n<link rel="dns-prefetch" href="https://assets.scryfall.com" />\n<link rel="dns-prefetch" href="https://img.scryfall.com" />\n\n<meta name="description" content="{1}{G}{U} \xe2\x80\xa2 Legendary Planeswalker \xe2\x80\x94 Oko \xe2\x80\xa2 Loyalty: 4 \xe2\x80\xa2 +2: Create a Food token. (It&#39;s an artifact with &quot;{2}, {T}, Sacrifice this artifact: You gain 3 life.&quot;) +1: Target artifact or creature loses all abilities and becomes a green Elk creature with base power and toughness 3/3. \xe2\x88\x925: Exchange control of target arti
# ...

# %%
#parsing the website with beautifulsoup

#import library

from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')


#check the parsed object using the pretify function of beautiful soup


print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Oko, Thief of Crowns · Throne of Eldraine (ELD) #197 · Scryfall Magic: The Gathering Search</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <link crossorigin="true" href="https://assets.scryfall.com" rel="preconnect"/>
# <link crossorigin="true" href="https://img.scryfall.com" rel="preconnect"/>
# <link href="https://assets.scryfall.com" rel="dns-prefetch"/>
# <link href="https://img.scryfall.com" rel="dns-prefetch"/>
# ...

# %%
#we check for the top level of the tags:

list(soup.children)

#we check the types of the elements in the children level

[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
#as we can see all the elements returned are beautiful soup objects 

#since it is a list, we can select the specific children by indexing, we chose tag that is the most important element
#that we have here. We assign it to be able to check inside of it

#we grab the tag 

html = list(soup.children)[2]

list(html.children)


#we can also check sublists of types of this tag if we want to
#[type(item) for item in list(html.children)]
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <title>Oko, Thief of Crowns · Throne of Eldraine (ELD) #197 · Scryfall Magic: The Gathering Search</title>
#  <meta content="width=device-width, initial-scale=1.0" name="viewport">
#  <link crossorigin="true" href="https://assets.scryfall.com" rel="preconnect"/>
#  <link crossorigin="true" href="https://img.scryfall.com" rel="preconnect"/>
#  <link href="https://assets.scryfall.com" rel="dns-prefetch"/>
#  <link href="https://img.scryfall.com" rel="dns-prefetch"/>
# ...

# %%
#We are interested in the card description and data. We see that this is located in head so we create an object of it

head = list(html.children)[1]

#Once we’ve isolated the tag, we can use the get_text method to extract all of the text inside the tag:

head.get_text()
# Out:
# '\n\nOko, Thief of Crowns · Throne of Eldraine (ELD) #197 · Scryfall Magic: The Gathering Search\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n{"@context":"http://schema.org","@type":"Organization","url":"https://scryfall.com","logo":"https://assets.scryfall.com/icon.png?v=a2c397e4e9d03627b7b5309d1e5c27df"}\n{"@context":"http://schema.org","@type":"WebSite","url":"https://scryfall.com","potentialAction":{"@type":"SearchAction","target":"https://scryfall.com/search?q={terms}&utm_source=google","query-input":"required name=terms"}}\n{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://scryfall.com/sets/eld","name":"Throne of Eldraine","image":"https://img.scryfall.com/sets/eld.svg?1567700076"}},{"@type":"ListItem","position":2,"item":{"@id":"https://scryfall.com/card/eld/197/oko-thief-of-crowns","name":"Oko, Thief of Crowns","image":"https://img.scryfall.com/cards/large/front/3/4/3462a
# ...

# %%
#What we did above was useful for figuring out how to navigate a page, but it took a lot of commands to do 
#something fairly simple. If we want to extract a single tag, we can instead use the find_all method, 
#which will find all the instances of a tag on a page.


soup = BeautifulSoup(page.content, 'html.parser')

#we can bring the title of the card through find all title and the effects and artist through find all p

#soup.find_all('title') finds the title of the card

soup.find_all('p') #shows the effect
# Out:
# [<p class="card-text-type-line" lang="en">
#            Legendary Planeswalker — Oko
#  </p>,
#  <p>+2: Create a Food token. <i>(It’s an artifact with “<abbr class="card-symbol card-symbol-2" title="two generic mana">{2}</abbr>, <abbr class="card-symbol card-symbol-T" title="tap this permanent">{T}</abbr>, Sacrifice this artifact: You gain 3 life.”)</i></p>,
#  <p>+1: Target artifact or creature loses all abilities and becomes a green Elk creature with base power and toughness 3/3.</p>,
#  <p>−5: Exchange control of target artifact or creature you control and target creature an opponent controls with power 3 or less.</p>,
#  <p class="card-text-artist">
#            Illustrated by
#              <a data-track='{"category":"Card Detail","action":"Navigate","label":"Artist"}' href="/search?q=a%3A%E2%80%9CYongjae+Choi%E2%80%9D&amp;unique=art">Yongjae Choi</a>
#  </p>,
#  <p>
#          Portions of Scryfall are unofficial Fan Content permitted under
# ...

# %%
#Finding a way to get the card title 


soup.find_all('title')[0]
# Out:
# <title>Oko, Thief of Crowns · Throne of Eldraine (ELD) #197 · Scryfall Magic: The Gathering Search</title>

# %%
#Finding a way to get the card text directly 

soup.find_all(class_="card-text-oracle")
# Out:
# [<div class="card-text-oracle">
#  <p>+2: Create a Food token. <i>(It’s an artifact with “<abbr class="card-symbol card-symbol-2" title="two generic mana">{2}</abbr>, <abbr class="card-symbol card-symbol-T" title="tap this permanent">{T}</abbr>, Sacrifice this artifact: You gain 3 life.”)</i></p>
#  <p>+1: Target artifact or creature loses all abilities and becomes a green Elk creature with base power and toughness 3/3.</p>
#  <p>−5: Exchange control of target artifact or creature you control and target creature an opponent controls with power 3 or less.</p>
#  </div>]

# %%
#finding a way to capture the type of card

soup.find_all(class_="card-text-type-line")
# Out:
# [<p class="card-text-type-line" lang="en">
#            Legendary Planeswalker — Oko
#  </p>]

# %%
#finding a way to capture the artist of the card 

soup.find_all(class_="card-text-artist")
# Out:
# [<p class="card-text-artist">
#            Illustrated by
#              <a data-track='{"category":"Card Detail","action":"Navigate","label":"Artist"}' href="/search?q=a%3A%E2%80%9CYongjae+Choi%E2%80%9D&amp;unique=art">Yongjae Choi</a>
#  </p>]

# %%
#Finding a way to capture the image URL


soup.findAll('img')[0].get('src')
# Out:
# 'https://img.scryfall.com/cards/large/front/3/4/3462a3d0-5552-49fa-9eb7-100960c55891.jpg?1567700076'

# %%
#getting all the clean elements and putting them into variables 

#getting title
card_title = soup.find_all('title')[0].get_text().split('·')[0].strip()

#getting edition 

card_edition = soup.find_all('title')[0].get_text().split('·')[1].strip()

#getting text 

card_text = soup.find_all(class_="card-text-oracle")[0].get_text().strip()

#getting type of card

card_type = soup.find_all(class_="card-text-type-line")[0].get_text().strip()


#getting artist 

card_artist = soup.select('p a')[0].get_text().strip()

#getting the card image link

card_image_link = soup.findAll('img')[0].get('src')

#image = soup.find_all('img')[0].get_text()

print('Title:"{}",\nEdition:"{}",\nText:"{}",\nType of card:"{}",\nArtist = "{}",\nImage = "{}"'.format(title,edition,text,type_of_card,artist,image))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-28c98ebc2fd8> in <module>
#      27 #image = soup.find_all('img')[0].get_text()
#      28
# ---> 29 print('Title:"{}",\nEdition:"{}",\nText:"{}",\nType of card:"{}",\nArtist = "{}",\nImage = "{}"'.format(title,edition,text,type_of_card,artist,image))
#
# NameError: name 'title' is not defined

# %%
#Trying to set up a mongo conection to load the data into mongo

from pymongo import MongoClient

#setting up connection to local client

client = MongoClient()

#setting up connection to magic_cards database

db = client.magic_cards

#setting up connection to cards_collection collection

cards_collection = db.cards_collection


#inserting a card

oko = {
    'title':card_title,
    'edition':card_edition,
    'text':card_text,
    'type of card':card_type,
    'artist':card_artist,
    'image':card_image_link
}

#result = cards_collection.insert_one(oko)

print('One post: {0}'.format(result.inserted_id))


#checking the inserted id

finding_oko = cards_collection.find_one({'artist': 'Yongjae Choi'})

print(finding_oko)

# %%
#Checking if MongoEngine is better

#import package

from mongoengine import * 


#establishing connections

connect('mongoengine_test', host='localhost', port=27017)


#creating a class for my cards objects 

class Card(Document):
    title = StringField(required=True)
    edition = StringField(required=True)
    text = StringField(required=True)
    type_of_card = StringField(required=True)
    artist = StringField(required=True)
    image = StringField(required=True)
    
    @classmethod
    def save(cls):
        file = {'title':title,
                'edition':edition,
                'text':text,
                'type of card':type_of_card,
                'artist':artist,
                'image':image
               }
        
        cards_collection.insert_one(file)

# %%
#trying to work with the class

card_1 = Card(
             title = card_title,
             edition = card_edition,
             text = card_text,
             type_of_card = card_type,
             artist = card_artist,
             image = card_image_link
             )

card_1.save()
